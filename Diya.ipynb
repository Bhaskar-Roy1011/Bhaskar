# %%
print("Hello World")
# Out:
# Hello World

# %%
a=5
b=2
sum=a+b
print(sum)
# Out:
# 7

# %%
a=5
b=3
print(a+b)
# Out:
# 8

# %%
a=5
b=3
diff = a-b
print(diff)
# Out:
# 2

# %%
a= 5
b=2
print(a-b)
# Out:
# 3

# %%
a= 6
b= 2
div = a/b
print(div)
# Out:
# 3.0

# %%
print(a/b)
# Out:
# 3.0

# %%
mul=a*b
print(mul)
# Out:
# 12

# %%
print(a*b)

# %%
a = 7
b = 2
mod = a%b
print(mod)
# Out:
# 1

# %%
print(a%b)
# Out:
# 1

# %%
print(a**b)
# Out:
# 49

# %% [markdown]
# # Relational operator

# %%
a=5
b=2
print(a==b)
print(a!=b)
print(a>b)
print(a>=b)
print(a<b)
print(a<=b)
# Out:
# False
# True
# True
# True
# False
# False

# %%
print(a==b, a!=b)
# Out:
# False True

# %% [markdown]
# # Assignment Operator

# %%
num = 10
num = num+10
print(num)
# Out:
# 20

# %%
num = 10
num +=10 #same as num = num+10
print(num)
# Out:
# 20

# %%
num=10
num*=2
print("num: ", num)
# Out:
# num:  20

# %%
num = 10
num /= 2
print("num: ", num)
# Out:
# num:  5.0

# %%
num = 11
num %=2
print("num: ", num)
# Out:
# num:  1

# %%
num = 10
num **=2
print("num: ", num)
# Out:
# num:  100

# %% [markdown]
# # Logical Operator

# %%
print(not False)
print(not True)
# Out:
# True
# False

# %%
a=50
b=20
print(not a>b)
# Out:
# False

# %%
val1= False
val2= True
print("AND operation: ", val1 and val2)
print("OR operation: ", (a==b) or (a>b))
print("NOT operation: ",  not (a==b) )
# Out:
# AND operation:  False
# OR operation:  True
# NOT operation:  True

# %% [markdown]
# # Type conversion

# %%
a = "2"
a= int(2)
print(type(a))
# Out:
# <class 'int'>

# %%
a =  2
a=str(a)
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# # Input in python
#  input() statement is used to accept values(using keyboard) from user and result for input() is always a string,
#  int(input()) for integer input,
#  float(input()) for floating input

# %%
input(" Enter your name: ")
# Out:
# 'Bhaskar Roy'

# %%
name = input("Enter your name: ")
print("Welcome ", name)
# Out:
# Welcome  Bhaskar Roy

# %%
val = input("Enter some value: ")
print(type(val), val)
# Out:
# <class 'str'> 44

# %%
val = int(input("Enter some value: "))
print(type(val), val)
# Out:
# <class 'int'> 45

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
marks = float(input("Enter marks: "))
print("Welcome ", name)
print("Your age is: ", age)
print(" and Your marks: ", marks)
# Out:
# Welcome  Bhaskar
# Your age is:  22
#  and Your marks:  95.0

# %% [markdown]
# # Write a program to input 2 numbers & print their sum, mul, div, diff.

# %%
a= int(input("Num1: "))
b= int(input("Num2: "))

print("Sum: ", a+b)
print("Mul: ", a*b)
print("Div: ", a/b)
print("Diff: ", a-b)
# Out:
# Sum:  12
# Mul:  20
# Div:  5.0
# Diff:  8

# %% [markdown]
# # Write a program to input side of a square & print its area.

# %%
side = int(input("Enter square side : "))
print("Area of square : ", side*side)
# Out:
# Area of square :  36

# %%
print("Area of square : ", side**2)
# Out:
# Area of square :  36

# %% [markdown]
# # Write a program to input 2 floating point numbers & print their average.
# # where a= 4.5 and b=4

# %%
a= float(input("Enter first number: "))
b= float(input("Enter second number: "))
print("Average is: ", (a+b)/2)
# Out:
# Average is:  4.25

# %% [markdown]
# # Write a program to input 2 int numbers, a and b.
# # Print True if a is greater than or equal to b. If not print false.
# # a=50 and b=20

# %%
a= int(input("first: "))
b= int(input("second: "))
print(a>=b)
# Out:
# True

# %% [markdown]
# # String: String is a data type that stores a sequence of characters.

# %%
str= "This is a string. We are creating it in python."
print(str)
str1 = """This is for next line.\n We use back slash n."""
print(str1)
# Out:
# This is a string. We are creating it in python.
# This is for next line.
#  We use back slash n.

# %% [markdown]
# # Slicing

# %%
str = "Bhaskar Roy"
print(len(str))
# Out:
# 11

# %%
str = "Bhaskar Roy"
print("Slicing 1: ",str[0:7])
print("Slicing 2: ",str[8:len(str)]) # same as print(str[8:12])
# Out:
# Slicing 1:  Bhaskar
# Slicing 2:  Roy

# %%
str = "Apple"
print(str[-3:-1])
# Out:
# pl

# %%
str = "Apple"
print(str[-5:-2])
# Out:
# App

# %% [markdown]
# # String Functions
# # str = "I am a coder."
# # str.endsWith("er.") #returns true if string ends with substring
# # str.capitalize()    #capitalizes 1st character
# # str.replace(old, new) #replace all occurrences of old with new
# # str.find(word)      #returns 1st index of 1st occurrence
# # str.count("am")     #counts the occurrence of substring in string

# %%
str = "I am studying python"
print(str.endswith("py"))
# Out:
# False

# %%
print(str.endswith("python"))
# Out:
# True

# %%
str = "i am a coder"
str = str.capitalize()
print(str)
# Out:
# I am a coder

# %%
str = "i am a coder"
print(str.capitalize())
print(str)
# Out:
# I am a coder
# i am a coder

# %%
str = "I am studying python from Youtube"
str = str.replace('o', 'a')
print(str)
# Out:
# I am studying pythan fram Yautube

# %%
str = "I am studying python from Youtube"
str = str.find("am")
print(str)
# Out:
# 2

# %%
str = "I am studying python from youtube"
str = str.count("y")
print(str)
# Out:
# 3

# %% [markdown]
# Q. Write a program to input user's first name & print its length.

# %%
name = input("Enter your name is: ")
print("Your name is: ", name)
print("Length of your name is: ", len(name))
# Out:
# Your name is:  Bhaskar Roy
# Length of your name is:  11

# %% [markdown]
# Q. Write a program to find the occurrence of '$' in a string

# %% [markdown]
# That mean how many times use the $ sign

# %%
str = "America use $"
str = str.count("$")
print(str)
# Out:
# 1

# %%
age = 21
if(age >=18):
    print("can vote & apply for license\n can drive")
# Out:
# can vote & apply for license
#  can drive

# %%
light = (input("Enter light color: "))
if (light == "red"):
    print("Stop")
elif(light=="green"):
    print("Go")
elif(light=="yellow"):
    print("look")
# Out:
# Stop

# %%
num = 5
if(num > 2):
    print("Greater than 2")
if(num > 3):
    print("Greater than 3")
# Out:
# Greater than 2
# Greater than 3

# %%
num = 5
if(num > 2):
    print("Greater than 2")
elif(num > 3):
        print("Greater than 3")
# Out:
# Greater than 2

# %%
light = (input("Press the light button: "))
if(light=="red"):
    print("stop")
elif(light=="green"):
    print("Go")
elif(light=="yellow"):
    print("Look")
else:
    print("Light is broken")
# Out:
# Light is broken

# %%
age = (input("Enter your age"))
if(age>= 18):
    print("Can vote & ")

# %%
marks = int(input("Enter your marks: "))

if(marks >= 90):
    print("Grade: A \nMarks:",marks)
elif(90 > marks >= 80):
    print("Grade: B \nMarks:",marks)
elif(80 > marks >= 70):
    print("Grade: C \nMarks:",marks)
elif(70 > marks > 33):
    print("Grade: D \nMarks:",marks)
else:
    print("Fail")
# Out:
# Grade: A
# Marks: 98

# %%
marks = int(input("Enter your marks: "))
if(marks >= 90):
    print("Grade: A")
if (marks >= 80 and marks < 90):
    print("Grade: B")
# Out:
# Grade: B

# %%
# Nesting
age = int(input("Enter Your Age: "))
if(age >= 18):
    if(age >= 80):
        print("cannot drive")
    else:
        print("can drive")
else:
    print("cannot drive")
# Out:
# cannot drive

# %% [markdown]
# Q. Write a program to check if a number entered by the user is odd or even.

# %%
num = int(input("Enter a number: "))
if(num%2 ==0):
    print("It is an Even number")
else:
    print("It is an Odd number")
# Out:
# It is an Odd number

# %%
num = int(input("Enter a number: "))
rem = num % 2
if(rem == 0):
    print("EVEN NUMBER")
else:
    print("ODD NUMBER")
# Out:
# EVEN NUMBER

# %% [markdown]
# Q. Write a program to find the greatest of 3 numbers entered by the user.

# %%
a = int(input("Enter a number: "))
b = int(input("Enter a number: "))
c = int(input("Enter a number: "))
if(a>=b>=c):
    print("First number is Greatest: ",a)
elif(b>=c):
    print("Second number is Greatest: ", b)
else:
    print("Third Number is Greatest: ", c)
# Out:
# Third Number is Greatest:  75

# %%
a = int(input("Enter a number: "))
b = int(input("Enter a number: "))
c = int(input("Enter a number: "))
if(a>=b and b>=c and a>=c):
    print("First number is Greatest: ",a)
elif(b>=c):
    print("Second number is Greatest: ", b)
else:
    print("Third Number is Greatest: ", c)
# Out:
# Second number is Greatest:  50

# %%
#correct code.
a = int(input("Enter a number: "))
b = int(input("Enter a number: "))
c = int(input("Enter a number: "))
if(a>=b>=c or a>b<c and a>=c ):
    print("First number is Greatest: ",a)
elif(a<b>=c): 
    print("Second number is Greatest: ", b)
elif(a<b<c or a>b<c and c>a):
    print("Third Number is Greatest: ", c)
# Out:
# First number is Greatest:  45

# %% [markdown]
# Q. Write a program to check if a number is a multiple of 7 or not.

# %%
x = int(input("Enter a number: "))
if(x % 7 == 0):
    print("multiple of 7")
else:
    print("Not a multiple.")
# Out:
# multiple of 7
